# %% [markdown]
# # Packages

# %%
import numpy as np
from matplotlib import pyplot as plt
from skimage import data
from skimage.restoration import inpaint

# %%
# Get Image
img = data.rocket()
plt.imshow(img, cmap=plt.cm.gray)

# %%
img[0:50, 500:550] = [0,0,0]
plt.imshow(img, cmap=plt.cm.gray)
