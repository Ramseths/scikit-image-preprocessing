# %% [markdown]
# # Packages

# %%
from skimage import morphology
from skimage import data
from matplotlib import pyplot as plt
from skimage.filters import threshold_otsu

# %%
def plot_comparison(original, sobel_image, title):
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(8, 6), sharex=True, sharey=True)
    ax1.imshow(original, cmap=plt.cm.gray)
    ax1.set_title("Original")
    ax1.axis("off")
    ax2.imshow(sobel_image, cmap=plt.cm.gray)
    ax2.set_title(title)
    ax2.axis("off")
    plt.show()

# %%
# Get Image
img = data.horse()
# Invert Thresholding
img = img <= threshold_otsu(img)
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %% [markdown]
# # Erosion

# %%
eroded_img = morphology.binary_erosion(img)
plot_comparison(img, eroded_img, "Eroded Image")

# %% [markdown]
# # Dilation

# %%
dilated_img = morphology.binary_dilation(img)
plot_comparison(img, eroded_img, "Dilated Image")
